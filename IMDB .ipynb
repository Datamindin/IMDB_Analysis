# %%
import pandas as pd

# %%
df = pd.read_csv("IMDB_Cleaned.csv")

# %%
df.head()
# Out:
#    Ranking                Movie Title  \
# 0        1   The Shawshank Redemption
# 1        2              The Godfather
# 2        3            The Dark Knight
# 3        4      The Godfather Part II
# 4        5               12 Angry Men
#
#                                           Movie Link  \
# 0  https://www.imdb.com/title/tt0111161/?ref_=cht...
# 1  https://www.imdb.com/title/tt0068646/?ref_=cht...
# 2  https://www.imdb.com/title/tt0468569/?ref_=cht...
# 3  https://www.imdb.com/title/tt0071562/?ref_=cht...
# 4  https://www.imdb.com/title/tt0050083/?ref_=cht...
#
#                                      Poster Img Link  Released_Year Duration  \
# 0  https://m.media-amazon.com/images/M/MV5BNDE3OD...           1994   2h 22m
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...           1972   2h 55m
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...           2008   2h 32m
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...           1974   3h 22m
# ...

# %%
df.describe()
# Out:
#           Ranking  Released_Year  IMDB Rating
# count  250.000000     250.000000   250.000000
# mean   125.500000    1986.712000     8.306800
# std     72.312977      25.331003     0.233864
# min      1.000000    1921.000000     8.000000
# 25%     63.250000    1966.250000     8.100000
# 50%    125.500000    1994.000000     8.200000
# 75%    187.750000    2007.000000     8.400000
# max    250.000000    2023.000000     9.300000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ranking          250 non-null    int64
#  1   Movie Title      250 non-null    object
#  2   Movie Link       250 non-null    object
#  3   Poster Img Link  250 non-null    object
#  4   Released_Year    250 non-null    int64
#  5   Duration         250 non-null    object
#  6   Certificate      249 non-null    object
#  7   IMDB Rating      250 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 15.8+ KB

# %%
df['Certificate'].value_counts()
# Out:
# R            97
# PG           37
# PG-13        35
# Not Rated    24
# G            18
# Passed       16
# Approved     14
# 18+           2
# TV-PG         1
# Unrated       1
# X             1
# 16+           1
# TV-MA         1
# GP            1
# Name: Certificate, dtype: int64

# %%
filt = df['Certificate'] == " "

# %%
df[filt]
# Out:
# Empty DataFrame
# Columns: [Ranking, Movie Title, Movie Link, Poster Img Link, Released_Year, Duration, Certificate, IMDB Rating]
# Index: []

# %%
df.isna().sum()
# Out:
# Ranking            0
# Movie Title        0
# Movie Link         0
# Poster Img Link    0
# Released_Year      0
# Duration           0
# Certificate        1
# IMDB Rating        0
# dtype: int64

# %%
df.isnull()
# Out:
#      Ranking  Movie Title  Movie Link  Poster Img Link  Released_Year  \
# 0      False        False       False            False          False
# 1      False        False       False            False          False
# 2      False        False       False            False          False
# 3      False        False       False            False          False
# 4      False        False       False            False          False
# ..       ...          ...         ...              ...            ...
# 245    False        False       False            False          False
# 246    False        False       False            False          False
# 247    False        False       False            False          False
# 248    False        False       False            False          False
# 249    False        False       False            False          False
#
#      Duration  Certificate  IMDB Rating
# 0       False        False        False
# 1       False        False        False
# ...

# %%
filt = df['Certificate']!=" "

# %%
df[df['Certificate'].isna()]
# Out:
#     Ranking Movie Title                                         Movie Link  \
# 76       77    Das Boot  https://www.imdb.com/title/tt0082096/?ref_=cht...
#
#                                       Poster Img Link  Released_Year Duration  \
# 76  https://m.media-amazon.com/images/M/MV5BNDBjMW...           1981   2h 29m
#
#    Certificate  IMDB Rating
# 76         NaN          8.4

# %%
df.fillna('R', inplace=True)

# %%
df[df['Certificate'].isna()]
# Out:
# Empty DataFrame
# Columns: [Ranking, Movie Title, Movie Link, Poster Img Link, Released_Year, Duration, Certificate, IMDB Rating]
# Index: []

# %%
df.isna().sum()
# Out:
# Ranking            0
# Movie Title        0
# Movie Link         0
# Poster Img Link    0
# Released_Year      0
# Duration           0
# Certificate        0
# IMDB Rating        0
# dtype: int64

# %%
# df.set_index('Ranking', inplace=True)

# %%
df
# Out:
#      Ranking                Movie Title  \
# 0          1   The Shawshank Redemption
# 1          2              The Godfather
# 2          3            The Dark Knight
# 3          4      The Godfather Part II
# 4          5               12 Angry Men
# ..       ...                        ...
# 245      246                   The Help
# 246      247                    Persona
# 247      248              Life of Brian
# 248      249                    Aladdin
# 249      250         Dances with Wolves
#
#                                             Movie Link  \
# 0    https://www.imdb.com/title/tt0111161/?ref_=cht...
# 1    https://www.imdb.com/title/tt0068646/?ref_=cht...
# 2    https://www.imdb.com/title/tt0468569/?ref_=cht...
# 3    https://www.imdb.com/title/tt0071562/?ref_=cht...
# 4    https://www.imdb.com/title/tt0050083/?ref_=cht...
# ..                                                 ...
# 245  https://www.imdb.com/title/tt1454029/?ref_=cht...
# ...

# %%
df2 = df.copy()

# %%
df2
# Out:
#      Ranking                Movie Title  \
# 0          1   The Shawshank Redemption
# 1          2              The Godfather
# 2          3            The Dark Knight
# 3          4      The Godfather Part II
# 4          5               12 Angry Men
# ..       ...                        ...
# 245      246                   The Help
# 246      247                    Persona
# 247      248              Life of Brian
# 248      249                    Aladdin
# 249      250         Dances with Wolves
#
#                                             Movie Link  \
# 0    https://www.imdb.com/title/tt0111161/?ref_=cht...
# 1    https://www.imdb.com/title/tt0068646/?ref_=cht...
# 2    https://www.imdb.com/title/tt0468569/?ref_=cht...
# 3    https://www.imdb.com/title/tt0071562/?ref_=cht...
# 4    https://www.imdb.com/title/tt0050083/?ref_=cht...
# ..                                                 ...
# 245  https://www.imdb.com/title/tt1454029/?ref_=cht...
# ...

# %%
df2.drop(df2.iloc[:,[2,3]], axis=1, inplace =True)

# %%
df3 = pd.read_csv("imdb_top_1000.csv")

# %%
df3
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df3.rename(columns = {'Series_Title':'Movie Title'}, inplace =True)

# %%
df3.drop(columns=['Poster_Link'], axis=1, inplace=True)

# %%
df3
# Out:
#                   Movie Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# ...

# %%
df2['Movie Title']
print(len(df2['Movie Title'][0]))
# Out:
# 25

# %%
df3['Movie Title']
print(len(df3['Movie Title'][0]))
# Out:
# 24

# %%
df2['Movie Title'][0] == df3['Movie Title'][0]
# Out:
# False

# %%
movies_list = []
for i in df['Movie Title']:
    movies = i.strip()
    movies_list.append(movies)

# %%
movies_list
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather Part II',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Good, the Bad and the Ugly',
#  'Forrest Gump',
#  'Fight Club',
#  'The Lord of the Rings: The Two Towers',
#  'Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Matrix',
#  'Goodfellas',
#  'Spider-Man: Across the Spider-Verse',
#  "One Flew Over the Cuckoo's Nest",
#  'Se7en',
#  "It's a Wonderful Life",
#  'Seven Samurai',
#  'The Silence of the Lambs',
#  'Interstellar',
#  'Saving Private Ryan',
#  'City of God',
#  'Life Is Beautiful',
#  'The Green Mile',
#  'Star Wars: Episode IV - A New Hope',
#  'Terminator 2: Judgment Day',
#  'Back to the Future',
#  'Spirited Away',
#  'The Pianist',
#  'Psycho',
#  'Parasite',
#  'Gladiator',
#  'The Lion King',
#  'Léon: The Professional',
# ...

# %%
df2['Movie Title'] = pd.DataFrame(movies_list)

# %%
df2
# Out:
#      Ranking               Movie Title  Released_Year Duration Certificate  \
# 0          1  The Shawshank Redemption           1994   2h 22m           R
# 1          2             The Godfather           1972   2h 55m           R
# 2          3           The Dark Knight           2008   2h 32m       PG-13
# 3          4     The Godfather Part II           1974   3h 22m           R
# 4          5              12 Angry Men           1957   1h 36m    Approved
# ..       ...                       ...            ...      ...         ...
# 245      246                  The Help           2011   2h 26m       PG-13
# 246      247                   Persona           1966   1h 23m   Not Rated
# 247      248             Life of Brian           1979   1h 34m           R
# 248      249                   Aladdin           1992   1h 30m           G
# 249      250        Dances with Wolves           1990    3h 1m       PG-13
#
#      IMDB Rating
# 0            9.3
# 1            9.2
# ...

# %%
len(df2['Movie Title'][0])
# Out:
# 24

# %%
len(df3['Movie Title'][0])
# Out:
# 24

# %%
df2
# Out:
#      Ranking               Movie Title  Released_Year Duration Certificate  \
# 0          1  The Shawshank Redemption           1994   2h 22m           R
# 1          2             The Godfather           1972   2h 55m           R
# 2          3           The Dark Knight           2008   2h 32m       PG-13
# 3          4     The Godfather Part II           1974   3h 22m           R
# 4          5              12 Angry Men           1957   1h 36m    Approved
# ..       ...                       ...            ...      ...         ...
# 245      246                  The Help           2011   2h 26m       PG-13
# 246      247                   Persona           1966   1h 23m   Not Rated
# 247      248             Life of Brian           1979   1h 34m           R
# 248      249                   Aladdin           1992   1h 30m           G
# 249      250        Dances with Wolves           1990    3h 1m       PG-13
#
#      IMDB Rating
# 0            9.3
# 1            9.2
# ...

# %%
df3
# Out:
#                   Movie Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# ...

# %%
df2['Movie Title'][0] == df3['Movie Title'][0]
# Out:
# True

# %%
new_df = df2.merge(df3[['Movie Title','Runtime','Genre','IMDB_Rating','Overview','Meta_score','Director','Star1','Star2','Star3','Star4','No_of_Votes','Gross' ]])

# %%
new_df
# Out:
#      Ranking               Movie Title  Released_Year Duration Certificate  \
# 0          1  The Shawshank Redemption           1994   2h 22m           R
# 1          2             The Godfather           1972   2h 55m           R
# 2          3           The Dark Knight           2008   2h 32m       PG-13
# 3          5              12 Angry Men           1957   1h 36m    Approved
# 4          6          Schindler's List           1993   3h 15m           R
# ..       ...                       ...            ...      ...         ...
# 189      246                  The Help           2011   2h 26m       PG-13
# 190      247                   Persona           1966   1h 23m   Not Rated
# 191      248             Life of Brian           1979   1h 34m           R
# 192      249                   Aladdin           1992   1h 30m           G
# 193      250        Dances with Wolves           1990    3h 1m       PG-13
#
# ...

# %%
new_df.isna().sum()
# Out:
# Ranking           0
# Movie Title       0
# Released_Year     0
# Duration          0
# Certificate       0
# IMDB Rating       0
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Overview          0
# Meta_score       11
# Director          0
# Star1             0
# Star2             0
# Star3             0
# Star4             0
# No_of_Votes       0
# Gross            13
# dtype: int64

# %%
new_df['Meta_score'].median()
# Out:
# 84.0

# %%
new_df['Gross'].median()
# Out:
# 54513740.0

# %%
# net_gross= []
# for i in new_df['Gross']:
#     updated_gross = i.replace(',','')
#     updated_gross = int(updated_gross)
#     net_gross.append(updated_gross)

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(strategy='median')

# %%
a = imp.fit(new_df[['Meta_score','Gross']])

# %%
imputed_df = a.transform(new_df[['Meta_score','Gross']])

# %%
imputed_df
# Out:
# array([[8.00000000e+01, 2.83414690e+07],
#        [1.00000000e+02, 1.34966411e+08],
#        [8.40000000e+01, 5.34858444e+08],
#        [9.60000000e+01, 4.36000000e+06],
#        [9.40000000e+01, 9.68988180e+07],
#        [9.40000000e+01, 3.77845905e+08],
#        [9.40000000e+01, 1.07928762e+08],
#        [9.20000000e+01, 3.15544750e+08],
#        [8.20000000e+01, 3.30252182e+08],
#        [6.60000000e+01, 3.70301020e+07],
#        [8.70000000e+01, 3.42551365e+08],
#        [7.40000000e+01, 2.92576195e+08],
#        [8.20000000e+01, 2.90475067e+08],
#        [7.30000000e+01, 1.71479930e+08],
#        [9.00000000e+01, 4.68363940e+07],
#        [8.30000000e+01, 1.12000000e+08],
#        [6.50000000e+01, 1.00125643e+08],
#        [8.90000000e+01, 5.45137400e+07],
#        [8.50000000e+01, 1.30742922e+08],
#        [7.40000000e+01, 1.88020017e+08],
#        [9.10000000e+01, 2.16540909e+08],
#        [6.10000000e+01, 1.36801374e+08],
#        [7.50000000e+01, 2.04843350e+08],
# ...

# %%
new_df.isna().sum()
# Out:
# Ranking           0
# Movie Title       0
# Released_Year     0
# Duration          0
# Certificate       0
# IMDB Rating       0
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Overview          0
# Meta_score       11
# Director          0
# Star1             0
# Star2             0
# Star3             0
# Star4             0
# No_of_Votes       0
# Gross            13
# dtype: int64

# %%
concat_df = pd.DataFrame(imputed_df, columns=['New_Meta_score','New_Gross'])

# %%
new_df = pd.concat([new_df, concat_df], axis= 1)

# %%
new_df
# Out:
#      Ranking               Movie Title  Released_Year Duration Certificate  \
# 0          1  The Shawshank Redemption           1994   2h 22m           R
# 1          2             The Godfather           1972   2h 55m           R
# 2          3           The Dark Knight           2008   2h 32m       PG-13
# 3          5              12 Angry Men           1957   1h 36m    Approved
# 4          6          Schindler's List           1993   3h 15m           R
# ..       ...                       ...            ...      ...         ...
# 189      246                  The Help           2011   2h 26m       PG-13
# 190      247                   Persona           1966   1h 23m   Not Rated
# 191      248             Life of Brian           1979   1h 34m           R
# 192      249                   Aladdin           1992   1h 30m           G
# 193      250        Dances with Wolves           1990    3h 1m       PG-13
#
# ...

# %%
new_runtime= []
for i in new_df["Runtime"]:
    x = i.replace('min', '').strip()
    new_runtime.append(x)

# %%
new_df['Runtime'] = new_runtime

# %%
new_df
# Out:
#      Ranking               Movie Title  Released_Year Certificate  \
# 0          1  The Shawshank Redemption           1994           R
# 1          2             The Godfather           1972           R
# 2          3           The Dark Knight           2008       PG-13
# 3          5              12 Angry Men           1957    Approved
# 4          6          Schindler's List           1993           R
# ..       ...                       ...            ...         ...
# 189      246                  The Help           2011       PG-13
# 190      247                   Persona           1966   Not Rated
# 191      248             Life of Brian           1979           R
# 192      249                   Aladdin           1992           G
# 193      250        Dances with Wolves           1990       PG-13
#
#      IMDB Rating Runtime                         Genre  IMDB_Rating  \
# 0            9.3     142                         Drama          9.3
# ...

# %%
new_df.isna().sum()
# Out:
# Ranking            0
# Movie Title        0
# Released_Year      0
# Duration           0
# Certificate        0
# IMDB Rating        0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score        11
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross             13
# New_Meta_score     0
# New_Gross          0
# dtype: int64

# %%
new_df.drop(new_df.iloc[:, [3,10, 17]], axis=1, inplace=True)

# %%
new_df
# Out:
#      Ranking               Movie Title  Released_Year Certificate  \
# 0          1  The Shawshank Redemption           1994           R
# 1          2             The Godfather           1972           R
# 2          3           The Dark Knight           2008       PG-13
# 3          5              12 Angry Men           1957    Approved
# 4          6          Schindler's List           1993           R
# ..       ...                       ...            ...         ...
# 189      246                  The Help           2011       PG-13
# 190      247                   Persona           1966   Not Rated
# 191      248             Life of Brian           1979           R
# 192      249                   Aladdin           1992           G
# 193      250        Dances with Wolves           1990       PG-13
#
#      IMDB Rating  Runtime                         Genre  IMDB_Rating  \
# 0            9.3  142 min                         Drama          9.3
# ...

# %%
new_df.isna().sum()
# Out:
# Ranking           0
# Movie Title       0
# Released_Year     0
# Certificate       0
# IMDB Rating       0
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Overview          0
# Director          0
# Star1             0
# Star2             0
# Star3             0
# Star4             0
# No_of_Votes       0
# New_Meta_score    0
# New_Gross         0
# dtype: int64

# %%
new_df.to_csv("IMDB_Visuals.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
from matplotlib import pyplot as plt

# %%
numerical_attributes = ['IMDB_Rating', 'New_Meta_score', 'No_of_Votes', 'New_Gross']
new_df[numerical_attributes].hist(figsize = (15, 6), color = 'blue',  layout = (2, 2))

# %% [markdown]
# # Analysis Based on Directors

# %%
new_df['Director'].value_counts().sort_values(ascending = False)
# Out:
# Martin Scorsese      7
# Christopher Nolan    7
# Stanley Kubrick      6
# Alfred Hitchcock     6
# Steven Spielberg     6
#                     ..
# Harold Ramis         1
# John Ford            1
# Lasse Hallström      1
# Stuart Rosenberg     1
# Kevin Costner        1
# Name: Director, Length: 119, dtype: int64

# %%
dir_plot1 = new_df['Director'].value_counts().sort_values(ascending = False).head(10)

# %%
dir_plot1.plot(kind='bar')
plt.xlabel('Director Name') 
plt.ylabel('') 
  
# displaying the title
plt.title("Most Appearences for Directors")
# Out:
# Text(0.5, 1.0, 'Most Appearences for Directors')

# %%
dir_group = new_df.groupby(['Director'])

# %%
dir_group['New_Gross'].mean().sort_values(ascending=False)
# Out:
# Director
# Anthony Russo           7.685942e+08
# Roger Allers            4.227838e+08
# David Yates             3.810112e+08
# Peter Jackson           3.453140e+08
# Todd Phillips           3.354513e+08
#                             ...
# Michael Curtiz          1.024560e+06
# Carol Reed              4.491910e+05
# Mathieu Kassovitz       3.098110e+05
# John Ford               5.500000e+04
# Joseph L. Mankiewicz    1.017700e+04
# Name: New_Gross, Length: 119, dtype: float64

# %%
dir_plot2 = dir_group['New_Gross'].sum().sort_values(ascending=False).head(5)

# %%
dir_plot2.plot(kind='bar')

plt.xlabel('Director Name') 
plt.ylabel('') 
  
# displaying the title
plt.title("Most Gross Made by Directors")
# Out:
# Text(0.5, 1.0, 'Most Gross Made by Directors')

# %%
dir_plot3 = dir_group['New_Gross'].mean().sort_values(ascending=False).head(5)

# %%
dir_plot3.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Director'>

# %%
new_df['Star1'].value_counts()
# Out:
# Robert De Niro       6
# Tom Hanks            5
# Charles Chaplin      5
# Leonardo DiCaprio    5
# Christian Bale       4
#                     ..
# Cary Grant           1
# Peter O'Toole        1
# Takashi Shimura      1
# Harvey Keitel        1
# Kevin Costner        1
# Name: Star1, Length: 140, dtype: int64

# %%
star1 = new_df['Star1'].value_counts().head(5)

# %%
star1.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
s1_grp = new_df.groupby(['Star1'])

# %%
s1_grp['Genre'].value_counts().sort_values(ascending=False)
# Out:
# Star1              Genre
# Elijah Wood        Action, Adventure, Drama    3
# Robert De Niro     Crime, Drama                3
# Christian Bale     Action, Adventure           2
# Leonardo DiCaprio  Biography, Crime, Drama     2
# Ethan Hawke        Drama, Romance              2
#                                               ..
# Graham Chapman     Comedy                      1
# Gregory Peck       Crime, Drama                1
# Guy Pearce         Mystery, Thriller           1
# Harrison Ford      Action, Adventure           1
# Éric Toledano      Biography, Comedy, Drama    1
# Name: Genre, Length: 183, dtype: int64

# %%
new_df[new_df['Star1'] == 'Christian Bale']
# Out:
#     Ranking            Movie Title  Released_Year Certificate  IMDB Rating  \
# 2         3        The Dark Knight           2008       PG-13          9.0
# 31       43           The Prestige           2006       PG-13          8.5
# 53       70  The Dark Knight Rises           2012       PG-13          8.4
# 97      129          Batman Begins           2005       PG-13          8.2
#
#     Runtime                   Genre  IMDB_Rating  \
# 2   152 min    Action, Crime, Drama          9.0
# 31  130 min  Drama, Mystery, Sci-Fi          8.5
# 53  164 min       Action, Adventure          8.4
# 97  140 min       Action, Adventure          8.2
#
#                                              Overview           Director  \
# 2   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 31  After a tragic accident, two stage magicians e...  Christopher Nolan
# 53  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# ...

# %% [markdown]
# # Analysis On Genre

# %%
gen_grp = new_df.groupby(['Genre'])

# %%
gen_grp['New_Gross'].sum().sort_values(ascending=False)
# Out:
# Genre
# Animation, Adventure, Comedy    2.115420e+09
# Action, Adventure, Drama        2.082020e+09
# Action, Adventure, Sci-Fi       1.613064e+09
# Action, Adventure, Fantasy      9.050144e+08
# Action, Adventure               8.521633e+08
#                                     ...
# Action, Adventure, Comedy       1.033895e+06
# Film-Noir, Mystery, Thriller    4.491910e+05
# Comedy, Drama, War              2.884750e+05
# Drama, History                  5.500000e+04
# Crime, Thriller                 1.256200e+04
# Name: New_Gross, Length: 92, dtype: float64

# %%
gen_grp['New_Gross'].mean().sort_values(ascending=False)
# Out:
# Genre
# Animation, Adventure, Drama     422783777.0
# Action, Adventure, Drama        416404089.4
# Adventure, Drama, Fantasy       381011219.0
# Action, Adventure, Sci-Fi       322612829.4
# Action, Crime, Drama            302478744.5
#                                    ...
# Action, Adventure, Comedy         1033895.0
# Film-Noir, Mystery, Thriller       449191.0
# Comedy, Drama, War                 288475.0
# Drama, History                      55000.0
# Crime, Thriller                     12562.0
# Name: New_Gross, Length: 92, dtype: float64

# %%
new_df[new_df['Genre'] == "Crime, Thriller"]
# Out:
#      Ranking        Movie Title  Released_Year Certificate  IMDB Rating  \
# 125      161  Dial M for Murder           1954          PG          8.2
#
#     Runtime            Genre  IMDB_Rating  \
# 125     105  Crime, Thriller          8.2
#
#                                               Overview          Director  \
# 125  A former tennis player tries to arrange his wi...  Alfred Hitchcock
#
#            Star1        Star2            Star3          Star4  No_of_Votes  \
# 125  Ray Milland  Grace Kelly  Robert Cummings  John Williams       158335
#
#      New_Meta_score  New_Gross
# 125            75.0    12562.0

# %%
gen_plot1 = gen_grp['New_Gross'].sum().sort_values(ascending=False).head(5)

# %%
gen_plot1.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Genre'>

# %% [markdown]
# # Analysis Based on Voting

# %%
top_voted = new_df.sort_values(['No_of_Votes'], ascending = False)

# %%
top_voted
# Out:
#      Ranking                  Movie Title  Released_Year Certificate  \
# 0          1     The Shawshank Redemption           1994           R
# 2          3              The Dark Knight           2008       PG-13
# 11        14                    Inception           2010       PG-13
# 9         12                   Fight Club           1999           R
# 6          8                 Pulp Fiction           1994           R
# ..       ...                          ...            ...         ...
# 103      136        Judgment at Nuremberg           1961    Approved
# 72        97                        Ikiru           1952   Not Rated
# 173      224  The Best Years of Our Lives           1946    Approved
# 84       110                     Hamilton           2020       PG-13
# 180      231           To Be or Not to Be           1942      Passed
#
#      IMDB Rating  Runtime                      Genre  IMDB_Rating  \
# 0            9.3  142 min                      Drama          9.3
# ...

# %%
import seaborn as sns

# %%
fig=plt.subplots(figsize=(15,5))
g=sns.barplot(x=top_voted['Movie Title'][:7],y=top_voted['No_of_Votes'][:7], palette = 'hls')
g.set_title("Top Voted Movies")
plt.show()

# %%
fig=plt.subplots(figsize=(15,5))
x=sns.barplot(x=top_voted['Movie Title'][:7], y=top_voted['IMDB_Rating'][:7])
x.set_title("IMBD of top rated movies", weight = "bold")
plt.show()

# %%
fig = plt.subplots(figsize=(15,5))
g=sns.barplot(x=top_voted['Movie Title'][:7],y=top_voted['New_Meta_score'][:7], palette = 'husl')
g.set_title("Metascore of top rated movies", weight = "bold")
plt.show()

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=top_voted['Movie Title'][:7],y=top_voted['New_Gross'][:7], palette = 'husl')
g.set_title("Gross by top rated movies", weight = "bold")
plt.show()

# %% [markdown]
# # Highest Earning Movies

# %%
highest_earning = new_df.sort_values(['New_Gross'], ascending = False)

# %%
highest_earning
# Out:
#      Ranking             Movie Title  Released_Year Certificate  IMDB Rating  \
# 61        80       Avengers: Endgame           2019       PG-13          8.4
# 46        63  Avengers: Infinity War           2018       PG-13          8.4
# 2          3         The Dark Knight           2008       PG-13          9.0
# 53        70   The Dark Knight Rises           2012       PG-13          8.4
# 27        37           The Lion King           1994           G          8.5
# ..       ...                     ...            ...         ...          ...
# 72        97                   Ikiru           1952   Not Rated          8.3
# 182      233     The Grapes of Wrath           1940      Passed          8.1
# 39        54             City Lights           1931           G          8.5
# 125      161       Dial M for Murder           1954          PG          8.2
# 102      135           All About Eve           1950      Passed          8.2
#
# ...

# %%
fig,axs=plt.subplots(figsize=(23,5))
g=sns.barplot(x=highest_earning['Movie Title'][:7],y=highest_earning['New_Gross'][:7], palette = 'husl')
g.set_title("Movies with highest Gross", weight = "bold")
plt.show()

# %%
stars=['Star1','Star2','Star3','Star4']
fig,axs=plt.subplots(4,1,figsize=(20,15))
ax=0
for x in stars:
    axs[ax].bar(new_df[x].value_counts()[:10].index,new_df[x].value_counts()[:10])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %%
from collections import Counter

# %%
genre=[]
for x in new_df['Genre']:
    for y in x.split(','):
        genre.append(y.strip().lower())

# %%
genre
# Out:
# ['drama',
#  'crime',
#  'drama',
#  'action',
#  'crime',
#  'drama',
#  'crime',
#  'drama',
#  'biography',
#  'drama',
#  'history',
#  'action',
#  'adventure',
#  'drama',
#  'crime',
#  'drama',
#  'action',
#  'adventure',
#  'drama',
#  'drama',
#  'romance',
#  'drama',
#  'action',
#  'adventure',
#  'drama',
#  'action',
#  'adventure',
#  'sci-fi',
#  'action',
#  'adventure',
#  'fantasy',
#  'action',
#  'sci-fi',
#  'biography',
#  'crime',
#  'drama',
#  'drama',
#  'crime',
#  'drama',
#  'mystery',
#  'drama',
#  'family',
#  'fantasy',
#  'crime',
#  'drama',
#  'thriller',
#  'adventure',
#  'drama',
#  'sci-fi',
#  'drama',
#  'war',
#  'crime',
#  'drama',
#  'fantasy',
#  'action',
#  'sci-fi',
#  'adventure',
#  'comedy',
#  'sci-fi',
#  'biography',
#  'drama',
#  'music',
#  'horror',
#  'mystery',
#  'thriller',
#  'action',
#  'adventure',
#  'drama',
#  'animation',
#  'adventure',
#  'drama',
#  'drama',
#  'crime',
#  'drama',
#  'thriller',
# ...

# %%
count=Counter(genre)
count=count.most_common()[:10]
x,y=map(list,zip(*count))

# %%
count
# Out:
# [('drama', 134),
#  ('adventure', 53),
#  ('crime', 40),
#  ('action', 36),
#  ('comedy', 36),
#  ('thriller', 28),
#  ('biography', 25),
#  ('mystery', 22),
#  ('sci-fi', 20),
#  ('romance', 17)]

# %%
y
# Out:
# [134, 53, 40, 36, 36, 28, 25, 22, 20, 17]

# %%
x
# Out:
# ['drama',
#  'adventure',
#  'crime',
#  'action',
#  'comedy',
#  'thriller',
#  'biography',
#  'mystery',
#  'sci-fi',
#  'romance']

# %%
fig=plt.subplots(figsize=(20,5))
g=sns.barplot(x = y,y = x)
g.set_ylabel("Genres", weight = "bold")
g.set_title("Top Ten Genres", weight = "bold")
plt.show()
